# %%
import pandas as pd
from uszipcode import SearchEngine, SimpleZipcode
from datasource import DataSource

# %% [markdown]
# Below are examples on how to use the class

# %%
# Initializing the class with the files from the census
d = DataSource('census//wc//meta.csv','census//wc//data.csv')

# %%
# Getting the panda with the data
# size 1x1373
d.get_data()
# Out:
#              GEO_ID                           NAME S0501_C01_001E  \
# 1  1600000US0683346  Walnut Creek city, California          69567
#
#   S0501_C01_001M S0501_C01_002E S0501_C01_002M S0501_C01_003E S0501_C01_003M  \
# 1            148           46.3            1.2           53.7            1.2
#
#   S0501_C01_004E S0501_C01_004M  ... S0501_C05_133M S0501_C05_134E  \
# 1            4.9            0.6  ...           15.3           34.4
#
#   S0501_C05_134M S0501_C05_135E S0501_C05_135M S0501_C05_136E S0501_C05_136M  \
# 1           15.3           1495            312           57.5           10.2
#
#   S0501_C05_137E S0501_C05_137M zip_codes
# 1           42.5           10.2
#
# [1 rows x 1373 columns]

# %%
# This changes the data to have different columns names
d.change_col_name()
# Out:
#              GEO_ID                           NAME  \
# 1  1600000US0683346  Walnut Creek city, California
#
#   Estimate!!Total!!Total population Margin of Error!!Total!!Total population  \
# 1                             69567                                      148
#
#   Estimate!!Total!!Total population!!SEX AND AGE!!Male  \
# 1                                               46.3
#
#   Margin of Error!!Total!!Total population!!SEX AND AGE!!Male  \
# 1                                                1.2
#
#   Estimate!!Total!!Total population!!SEX AND AGE!!Female  \
# 1                                               53.7
#
#   Margin of Error!!Total!!Total population!!SEX AND AGE!!Female  \
# 1                                                1.2
#
#   Estimate!!Total!!Total population!!SEX AND AGE!!Under 5 years  \
# 1                                                4.9
#
#   Margin of Error!!Total!!Total population!!SEX AND AGE!!Under 5 years  ...  \
# 1                                                0.6                    ...
#
#   Margin of Error!!Foreign born; Not a U.S. citizen!!Owner-occupied housing units!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS!!Less than 30 percent  \
# 1                                               15.3
#
#   Estimate!!Foreign born; Not a U.S. citizen!!Owner-occupied housing units!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS!!30 percent or more  \
# 1                                               34.4
#
#   Margin of Error!!Foreign born; Not a U.S. citizen!!Owner-occupied housing units!!SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS!!30 percent or more  \
# 1                                               15.3
#
#   Estimate!!Foreign born; Not a U.S. citizen!!Renter-occupied housing units  \
# 1                                               1495
#
#   Margin of Error!!Foreign born; Not a U.S. citizen!!Renter-occupied housing units  \
# 1                                                312
#
#   Estimate!!Foreign born; Not a U.S. citizen!!Renter-occupied housing units!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS!!Less than 30 percent  \
# 1                                               57.5
#
#   Margin of Error!!Foreign born; Not a U.S. citizen!!Renter-occupied housing units!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS!!Less than 30 percent  \
# 1                                               10.2
#
#   Estimate!!Foreign born; Not a U.S. citizen!!Renter-occupied housing units!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS!!30 percent or more  \
# 1                                               42.5
#
#   Margin of Error!!Foreign born; Not a U.S. citizen!!Renter-occupied housing units!!GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS!!30 percent or more  \
# 1                                               10.2
#
#   zip_codes
# 1
#
# [1 rows x 1373 columns]
